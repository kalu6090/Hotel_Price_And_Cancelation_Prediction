# %% [markdown]
# ### Loading Libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_text
from sklearn import tree

# %% [markdown]
# ### Loading and Cleaning Data

# %%
df = pd.read_csv('../Data/clean_data_xtra_features.csv')
df = df.dropna(axis=0)
df = df.drop(columns=['Unnamed: 0'], axis=1)
df.describe()
# Out:
#           lead_time  arrival_date_month  arrival_date_week_number  \
# count  72514.000000        72514.000000              72514.000000
# mean      81.028105            6.521748                 27.058375
# std       91.384938            3.127892                 13.793632
# min        0.000000            1.000000                  1.000000
# 25%        9.000000            4.000000                 16.000000
# 50%       47.000000            7.000000                 28.000000
# 75%      126.000000            9.000000                 38.000000
# max      709.000000           12.000000                 53.000000
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count               72514.000000             72514.000000
# mean                   15.833039                 0.939336
# std                     8.776169                 0.986946
# min                     1.000000                 0.000000
# 25%                     8.000000                 0.000000
# 50%                    16.000000                 1.000000
# 75%                    23.000000                 2.000000
# max                    31.000000                19.000000
#
#        stays_in_week_nights        adults      children        babies  \
# count          72514.000000  72514.000000  72514.000000  72514.000000
# mean               2.485037      1.839824      0.103677      0.010205
# std                1.897016      0.502700      0.393228      0.112666
# min                0.000000      0.000000      0.000000      0.000000
# 25%                1.000000      2.000000      0.000000      0.000000
# 50%                2.000000      2.000000      0.000000      0.000000
# 75%                3.000000      2.000000      0.000000      0.000000
# max               50.000000      4.000000      3.000000     10.000000
#
#        is_repeated_guest  ...  refundable_deposit  nonrefundable_deposit  \
# count       72514.000000  ...        72514.000000                72514.0
# mean            0.037538  ...            0.001738                    0.0
# std             0.190076  ...            0.041649                    0.0
# min             0.000000  ...            0.000000                    0.0
# 25%             0.000000  ...            0.000000                    0.0
# 50%             0.000000  ...            0.000000                    0.0
# 75%             0.000000  ...            0.000000                    0.0
# max             1.000000  ...            1.000000                    0.0
#
#        with_company   is_contract      is_group  is_transient  \
# count  72514.000000  72514.000000  72514.000000  72514.000000
# mean       0.071338      0.038268      0.006881      0.711063
# std        0.257390      0.191845      0.082669      0.453272
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      1.000000
# 75%        0.000000      0.000000      0.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000
#
#        is_transient_party   stay_length       holiday  weekend_current_stay
# count        72514.000000  72514.000000  72514.000000          72514.000000
# mean             0.243787      3.421932      0.042226              0.566663
# std              0.429369      2.533769      0.201106              0.495540
# min              0.000000      0.000000      0.000000              0.000000
# 25%              0.000000      2.000000      0.000000              0.000000
# 50%              0.000000      3.000000      0.000000              1.000000
# 75%              0.000000      4.000000      0.000000              1.000000
# max              1.000000     69.000000      1.000000              1.000000
#
# [8 rows x 39 columns]

# %% [markdown]
# ### Functions

# %%
def make_dataset(df, features, test_size=.3, normalize = True, binned= False):
    X = df.loc[:,features].values
    if normalize:
        X = StandardScaler().fit_transform(X)
    if binned:
        y = df['adr'].values
        bin_edges = np.linspace(np.min(y), np.max(y), 20)
        y_bin = np.zeros(np.shape(y))
        for i in range(len(y)):
            for j in range(len(bin_edges)):
                if y[i] < bin_edges[j]:
                    y_bin[i] = j
                    break
        y = y_bin
    else:
        y = df['adr'].values
        
    assert(len(X) == len(y))
    
    print("Total Size of data: ", len(X))
    
    test_size = int(len(X)*test_size)
    ind = [np.random.choice(range(len(X)), size=test_size, replace=False)]
    X_test = X[ind]
    y_test = y[ind]
    X_train = np.delete(X, ind, axis=0)
    y_train = np.delete(y, ind)
    
    print("Feature", features)
    print("X_train: ", np.shape(X_train))
    print("y_train: ", np.shape(y_train))
    print("X_test: ", np.shape(X_test))
    print("y_test: ", np.shape(y_test))
    
    return X_train, y_train, X_test, y_test

def calc_rmse(y_hat, y):
    return np.sqrt(np.mean((y_hat-y)**2))

def lin_reg(X_train, y_train, X_test, y_test):
    reg = LinearRegression().fit(X_train, y_train)
    y_hat = reg.predict(X_test)
    score = reg.score(X_test, y_test)
    root_mse = calc_rmse(y_hat, y_test)
    print("score: ", score)
    print("Root Mean Square Error: ", root_mse)
    
    return y_hat, score, root_mse

def plot_err_hist(y_hat, y, rmse):
    plt.hist(np.abs(y_hat - y))
    title = "Error Histogram: RMSE = " + str(np.round(rmse,2))
    plt.title(title)
    plt.xlabel("Error Bins")
    plt.ylabel("Frequency")
    plt.show()
    
def plot_y(y_hat, y):
    x = range(len(y_hat))
    plt.scatter(x,np.sort(y), alpha=.25, label="y")
    plt.scatter(x,np.sort(y_hat), alpha=.25, label="y_hat")
    plt.legend()
    plt.xlabel("Indicies")
    plt.ylabel("Average Daily Rate")
    plt.title("Predicted and Average Daily Rate")
    plt.show()
    
def make_PCA(X_train, X_test, features, thresh = .90):
    pca = PCA(thresh)
    pca.fit(X_train)
    
    var = pca.explained_variance_ratio_
    print("number components: ", len(var))
    evar = np.sum(var)
    print("Explained Variance:", evar)
    
    X_pcs_train = pca.transform(X_train)
    X_pcs_test = pca.transform(X_test)
    
    n_pcs= pca.components_.shape[0]
    most_important = [np.abs(pca.components_[i]).argmax() for i in range(n_pcs)]

    initial_feature_names = features
    most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]
    dic = {'PC{}'.format(i): most_important_names[i] for i in range(n_pcs)}
    
    return X_pcs_train, X_pcs_test, dic

def log_reg(X_train, y_train, X_test, y_test):
    clf = LogisticRegression(random_state=0).fit(X_train, y_train)
    y_hat = clf.predict(X_test)
    score = clf.score(X_test, y_test)
    rmse = calc_rmse(y_hat, y_test)
    print("score: ", score)
    print("Root Mean Square Error: ", rmse)
    return y_hat, score, rmse

def tree_class(X_train, y_train, X_test, y_test, verbose=False):
    X_train, y_train, X_test, y_test = make_dataset(df, features, binned=True)
    decision_tree = DecisionTreeClassifier(random_state=0)
    decision_tree = decision_tree.fit(X_train, y_train)
    y_hat = decision_tree.predict(X_test)
    r = export_text(decision_tree, feature_names=features)
    if verbose:
        print(r)
    rmse = calc_rmse(y_hat, y_test)
    return y_hat, rmse
    

def tree_reg(X_train,y_train, X_test, y_test):
    clf = tree.DecisionTreeRegressor()
    clf = clf.fit(X_train, y_train)
    y_hat = clf.predict(X_test)
    rmse = np.sqrt(np.mean((y_hat-y_test)**2))
    print("Root Mean Square Error: ", rmse)
    return y_hat, rmse

# %% [markdown]
# ### Loading All Features

# %%
features = list(df.columns)
features.remove('adr')
# features

# %% [markdown]
# ### Linear Regression, No PCA

# %%
X_train, y_train, X_test, y_test = make_dataset(df, features, binned=False)
y_hat, score, rmse = lin_reg(X_train, y_train, X_test, y_test)
plot_y(y_hat, y_test)
plot_err_hist(y_hat, y_test, rmse)
# Out:
# Total Size of data:  72514
# Feature ['lead_time', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'required_car_parking_spaces', 'total_of_special_requests', 'is_resort', 'bought_meal', 'is_international', 'aviation_segment', 'corporate_segment', 'groups_segment', 'offline_ta_to_segment', 'online_ta_segment', 'corporate_channel', 'direct_channel', 'gds_channel', 'ta_to_channel', 'no_deposit', 'refundable_deposit', 'nonrefundable_deposit', 'with_company', 'is_contract', 'is_group', 'is_transient', 'is_transient_party', 'stay_length', 'holiday', 'weekend_current_stay']
# X_train:  (50760, 38)
# y_train:  (50760,)
# X_test:  (21754, 38)
# y_test:  (21754,)
# score:  0.35467100654939354
# Root Mean Square Error:  38.07457784214267
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:24: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   X_test = X[ind]
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:25: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   y_test = y[ind]

# %% [markdown]
# ### Linear Regression, With PCA

# %%
X_train, y_train, X_test, y_test = make_dataset(df, features, binned=False)
X_train_pca, X_test_pca, col_dic = make_PCA(X_train, X_test, features, thresh=.95)
y_hat, score, rmse = lin_reg(X_train_pca, y_train, X_test_pca, y_test)
plot_y(y_hat, y_test)
plot_err_hist(y_hat, y_test, rmse)
# Out:
# Total Size of data:  72514
# Feature ['lead_time', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'required_car_parking_spaces', 'total_of_special_requests', 'is_resort', 'bought_meal', 'is_international', 'aviation_segment', 'corporate_segment', 'groups_segment', 'offline_ta_to_segment', 'online_ta_segment', 'corporate_channel', 'direct_channel', 'gds_channel', 'ta_to_channel', 'no_deposit', 'refundable_deposit', 'nonrefundable_deposit', 'with_company', 'is_contract', 'is_group', 'is_transient', 'is_transient_party', 'stay_length', 'holiday', 'weekend_current_stay']
# X_train:  (50760, 38)
# y_train:  (50760,)
# X_test:  (21754, 38)
# y_test:  (21754,)
# number components:  27
# Explained Variance: 0.9618982516930543
# score:  0.32663691341698
# Root Mean Square Error:  38.64207656319234
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:24: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   X_test = X[ind]
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:25: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   y_test = y[ind]

# %% [markdown]
# ### Logistic Regression, With PCA

# %%
X_train, y_train, X_test, y_test = make_dataset(df, features, binned=True)
y_hat, score, rmse = log_reg(X_train, y_train, X_test, y_test)
plot_y(y_hat, y_test)
plot_err_hist(y_hat, y_test, rmse)
# Out:
# Total Size of data:  72514
# Feature ['lead_time', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'required_car_parking_spaces', 'total_of_special_requests', 'is_resort', 'bought_meal', 'is_international', 'aviation_segment', 'corporate_segment', 'groups_segment', 'offline_ta_to_segment', 'online_ta_segment', 'corporate_channel', 'direct_channel', 'gds_channel', 'ta_to_channel', 'no_deposit', 'refundable_deposit', 'nonrefundable_deposit', 'with_company', 'is_contract', 'is_group', 'is_transient', 'is_transient_party', 'stay_length', 'holiday', 'weekend_current_stay']
# X_train:  (50760, 38)
# y_train:  (50760,)
# X_test:  (21754, 38)
# y_test:  (21754,)
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:24: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   X_test = X[ind]
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:25: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   y_test = y[ind]
# C:\Users\KatyLuttrell\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# score:  0.3837455180656431
# Root Mean Square Error:  1.6576400468620824

# %% [markdown]
# ### Logistic Regression, With PCA

# %%
X_train, y_train, X_test, y_test = make_dataset(df, features, binned=True)
X_train_pca, X_test_pca, col_dic = make_PCA(X_train, X_test, features, thresh=.95)
y_hat, score, rmse = log_reg(X_train_pca, y_train, X_test_pca, y_test)
plot_y(y_hat, y_test)
plot_err_hist(y_hat, y_test, rmse)
# Out:
# Total Size of data:  72514
# Feature ['lead_time', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'required_car_parking_spaces', 'total_of_special_requests', 'is_resort', 'bought_meal', 'is_international', 'aviation_segment', 'corporate_segment', 'groups_segment', 'offline_ta_to_segment', 'online_ta_segment', 'corporate_channel', 'direct_channel', 'gds_channel', 'ta_to_channel', 'no_deposit', 'refundable_deposit', 'nonrefundable_deposit', 'with_company', 'is_contract', 'is_group', 'is_transient', 'is_transient_party', 'stay_length', 'holiday', 'weekend_current_stay']
# X_train:  (50760, 38)
# y_train:  (50760,)
# X_test:  (21754, 38)
# y_test:  (21754,)
# number components:  27
# Explained Variance: 0.9632655063527198
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:24: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   X_test = X[ind]
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:25: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   y_test = y[ind]
# C:\Users\KatyLuttrell\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# score:  0.38526248046336303
# Root Mean Square Error:  1.6656075210219141

# %% [markdown]
# ### Decision Tree Classification, No PCA

# %%
X_train, y_train, X_test, y_test = make_dataset(df, features, binned=True)
y_hat, rmse = tree_class(X_train, y_train, X_test, y_test)
plot_y(y_hat, y_test)
plot_err_hist(y_hat, y_test, rmse)
# Out:
# Total Size of data:  72514
# Feature ['lead_time', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'required_car_parking_spaces', 'total_of_special_requests', 'is_resort', 'bought_meal', 'is_international', 'aviation_segment', 'corporate_segment', 'groups_segment', 'offline_ta_to_segment', 'online_ta_segment', 'corporate_channel', 'direct_channel', 'gds_channel', 'ta_to_channel', 'no_deposit', 'refundable_deposit', 'nonrefundable_deposit', 'with_company', 'is_contract', 'is_group', 'is_transient', 'is_transient_party', 'stay_length', 'holiday', 'weekend_current_stay']
# X_train:  (50760, 38)
# y_train:  (50760,)
# X_test:  (21754, 38)
# y_test:  (21754,)
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:24: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   X_test = X[ind]
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:25: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   y_test = y[ind]
# Total Size of data:  72514
# Feature ['lead_time', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'required_car_parking_spaces', 'total_of_special_requests', 'is_resort', 'bought_meal', 'is_international', 'aviation_segment', 'corporate_segment', 'groups_segment', 'offline_ta_to_segment', 'online_ta_segment', 'corporate_channel', 'direct_channel', 'gds_channel', 'ta_to_channel', 'no_deposit', 'refundable_deposit', 'nonrefundable_deposit', 'with_company', 'is_contract', 'is_group', 'is_transient', 'is_transient_party', 'stay_length', 'holiday', 'weekend_current_stay']
# X_train:  (50760, 38)
# y_train:  (50760,)
# X_test:  (21754, 38)
# y_test:  (21754,)
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:24: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   X_test = X[ind]
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:25: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   y_test = y[ind]

# %% [markdown]
# ### Decision Tree Classification, With PCA

# %%
X_train, y_train, X_test, y_test = make_dataset(df, features, binned=True)
X_train_pca, X_test_pca, col_dict = make_PCA(X_train, X_test, features, thresh=.95)
y_hat, rmse = tree_class(X_train_pca, y_train, X_test_pca, y_test, verbose=True)
plot_y(y_hat, y_test)
plot_err_hist(y_hat, y_test, rmse)
print(col_dict)
# Out:
# Total Size of data:  72514
# Feature ['lead_time', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'required_car_parking_spaces', 'total_of_special_requests', 'is_resort', 'bought_meal', 'is_international', 'aviation_segment', 'corporate_segment', 'groups_segment', 'offline_ta_to_segment', 'online_ta_segment', 'corporate_channel', 'direct_channel', 'gds_channel', 'ta_to_channel', 'no_deposit', 'refundable_deposit', 'nonrefundable_deposit', 'with_company', 'is_contract', 'is_group', 'is_transient', 'is_transient_party', 'stay_length', 'holiday', 'weekend_current_stay']
# X_train:  (50760, 38)
# y_train:  (50760,)
# X_test:  (21754, 38)
# y_test:  (21754,)
# number components:  27
# Explained Variance: 0.9617179447683926
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:24: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   X_test = X[ind]
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:25: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   y_test = y[ind]
# Total Size of data:  72514
# Feature ['lead_time', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'required_car_parking_spaces', 'total_of_special_requests', 'is_resort', 'bought_meal', 'is_international', 'aviation_segment', 'corporate_segment', 'groups_segment', 'offline_ta_to_segment', 'online_ta_segment', 'corporate_channel', 'direct_channel', 'gds_channel', 'ta_to_channel', 'no_deposit', 'refundable_deposit', 'nonrefundable_deposit', 'with_company', 'is_contract', 'is_group', 'is_transient', 'is_transient_party', 'stay_length', 'holiday', 'weekend_current_stay']
# X_train:  (50760, 38)
# y_train:  (50760,)
# X_test:  (21754, 38)
# y_test:  (21754,)
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:24: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   X_test = X[ind]
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:25: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   y_test = y[ind]
# |--- is_resort <= 0.25
# |   |--- online_ta_segment <= 0.02
# |   |   |--- lead_time <= 2.29
# |   |   |   |--- direct_channel <= 0.96
# |   |   |   |   |--- arrival_date_week_number <= 1.26
# |   |   |   |   |   |--- arrival_date_month <= -0.97
# |   |   |   |   |   |   |--- lead_time <= 0.19
# |   |   |   |   |   |   |   |--- with_company <= 1.67
# |   |   |   |   |   |   |   |   |--- lead_time <= -0.59
# |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= -1.20
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= -1.63
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  -1.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  -1.20
# |   |   |   |   |   |   |   |   |   |   |--- offline_ta_to_segment <= 0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- offline_ta_to_segment >  0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |--- lead_time >  -0.59
# |   |   |   |   |   |   |   |   |   |--- adults <= 1.31
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |--- adults >  1.31
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= -1.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  -1.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |--- with_company >  1.67
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= -1.71
# |   |   |   |   |   |   |   |   |   |--- total_of_special_requests <= -0.27
# |   |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights <= -1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights >  -1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- total_of_special_requests >  -0.27
# |   |   |   |   |   |   |   |   |   |   |--- stay_length <= -0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- stay_length >  -0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  -1.71
# |   |   |   |   |   |   |   |   |   |--- previous_bookings_not_canceled <= 1.31
# |   |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights <= 1.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights >  1.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- previous_bookings_not_canceled >  1.31
# |   |   |   |   |   |   |   |   |   |   |--- total_of_special_requests <= 0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- total_of_special_requests >  0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- lead_time >  0.19
# |   |   |   |   |   |   |   |--- is_transient_party <= 0.60
# |   |   |   |   |   |   |   |   |--- adults <= 1.31
# |   |   |   |   |   |   |   |   |   |--- lead_time <= 0.76
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= 0.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  0.73
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- lead_time >  0.76
# |   |   |   |   |   |   |   |   |   |   |--- adults <= -0.68
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |   |--- adults >  -0.68
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- adults >  1.31
# |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |--- is_transient_party >  0.60
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= -1.56
# |   |   |   |   |   |   |   |   |   |--- adults <= -0.68
# |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |--- adults >  -0.68
# |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  -1.56
# |   |   |   |   |   |   |   |   |   |--- stay_length <= -0.76
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- stay_length >  -0.76
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= 1.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  1.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- arrival_date_month >  -0.97
# |   |   |   |   |   |   |--- offline_ta_to_segment <= 0.70
# |   |   |   |   |   |   |   |--- arrival_date_week_number <= -0.33
# |   |   |   |   |   |   |   |   |--- previous_bookings_not_canceled <= 0.74
# |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.03
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.03
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= -0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  -0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- previous_bookings_not_canceled >  0.74
# |   |   |   |   |   |   |   |   |   |--- is_repeated_guest <= 2.43
# |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |   |   |--- is_repeated_guest >  2.43
# |   |   |   |   |   |   |   |   |   |   |--- is_international <= 0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- is_international >  0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |--- arrival_date_week_number >  -0.33
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= 1.19
# |   |   |   |   |   |   |   |   |   |--- booking_changes <= 0.30
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |--- booking_changes >  0.30
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  1.19
# |   |   |   |   |   |   |   |   |   |--- stay_length <= -0.36
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.56
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.56
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- stay_length >  -0.36
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.81
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.81
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- offline_ta_to_segment >  0.70
# |   |   |   |   |   |   |   |--- is_transient <= -0.47
# |   |   |   |   |   |   |   |   |--- weekend_current_stay <= -0.13
# |   |   |   |   |   |   |   |   |   |--- adults <= -0.68
# |   |   |   |   |   |   |   |   |   |   |--- corporate_channel <= 1.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- corporate_channel >  1.70
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- adults >  -0.68
# |   |   |   |   |   |   |   |   |   |   |--- stay_length <= -0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- stay_length >  -0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |--- weekend_current_stay >  -0.13
# |   |   |   |   |   |   |   |   |   |--- stay_length <= -0.36
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_month <= -0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_month >  -0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- stay_length >  -0.36
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_month <= 0.95
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_month >  0.95
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |--- is_transient >  -0.47
# |   |   |   |   |   |   |   |   |--- adults <= 1.31
# |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.75
# |   |   |   |   |   |   |   |   |   |   |--- previous_bookings_not_canceled <= 0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- previous_bookings_not_canceled >  0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.75
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 25
# |   |   |   |   |   |   |   |   |--- adults >  1.31
# |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 7.0
# |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= 0.39
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  0.39
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |--- arrival_date_week_number >  1.26
# |   |   |   |   |   |--- lead_time <= -0.55
# |   |   |   |   |   |   |--- lead_time <= -0.57
# |   |   |   |   |   |   |   |--- is_international <= 0.53
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= 1.41
# |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights <= -0.52
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= -0.95
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  -0.95
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights >  -0.52
# |   |   |   |   |   |   |   |   |   |   |--- corporate_segment <= 1.89
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- corporate_segment >  1.89
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  1.41
# |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.85
# |   |   |   |   |   |   |   |   |   |   |--- booking_changes <= 1.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- booking_changes >  1.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.85
# |   |   |   |   |   |   |   |   |   |   |--- is_transient <= -0.47
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- is_transient >  -0.47
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |--- is_international >  0.53
# |   |   |   |   |   |   |   |   |--- groups_segment <= 1.37
# |   |   |   |   |   |   |   |   |   |--- adults <= -0.68
# |   |   |   |   |   |   |   |   |   |   |--- required_car_parking_spaces <= 1.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- required_car_parking_spaces >  1.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- adults >  -0.68
# |   |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights <= -0.52
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights >  -0.52
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- groups_segment >  1.37
# |   |   |   |   |   |   |   |   |   |--- booking_changes <= 0.30
# |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |   |   |--- booking_changes >  0.30
# |   |   |   |   |   |   |   |   |   |   |--- stay_length <= -0.56
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |   |--- stay_length >  -0.56
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |--- lead_time >  -0.57
# |   |   |   |   |   |   |   |--- adults <= -0.68
# |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |--- adults >  -0.68
# |   |   |   |   |   |   |   |   |--- stay_length <= -0.36
# |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |--- stay_length >  -0.36
# |   |   |   |   |   |   |   |   |   |--- stays_in_weekend_nights <= -0.45
# |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |   |   |--- stays_in_weekend_nights >  -0.45
# |   |   |   |   |   |   |   |   |   |   |--- is_transient_party <= 0.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- is_transient_party >  0.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 7.0
# |   |   |   |   |   |--- lead_time >  -0.55
# |   |   |   |   |   |   |--- adults <= 1.31
# |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.56
# |   |   |   |   |   |   |   |   |--- children <= 1.01
# |   |   |   |   |   |   |   |   |   |--- stay_length <= -0.76
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- stay_length >  -0.76
# |   |   |   |   |   |   |   |   |   |   |--- with_company <= 1.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- with_company >  1.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- children >  1.01
# |   |   |   |   |   |   |   |   |   |--- booking_changes <= 3.82
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.42
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.42
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |--- booking_changes >  3.82
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= 0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.56
# |   |   |   |   |   |   |   |   |--- lead_time <= 0.96
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.67
# |   |   |   |   |   |   |   |   |   |   |--- children <= 1.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- children >  1.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.67
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- lead_time >  0.96
# |   |   |   |   |   |   |   |   |   |--- booking_changes <= 0.30
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= 1.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  1.46
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |--- booking_changes >  0.30
# |   |   |   |   |   |   |   |   |   |   |--- class: 7.0
# |   |   |   |   |   |   |--- adults >  1.31
# |   |   |   |   |   |   |   |--- lead_time <= 1.05
# |   |   |   |   |   |   |   |   |--- stays_in_weekend_nights <= -0.45
# |   |   |   |   |   |   |   |   |   |--- lead_time <= 0.26
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= 1.74
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  1.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- lead_time >  0.26
# |   |   |   |   |   |   |   |   |   |   |--- stay_length <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |   |--- stay_length >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 6.0
# |   |   |   |   |   |   |   |   |--- stays_in_weekend_nights >  -0.45
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= 1.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  1.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 8.0
# |   |   |   |   |   |   |   |--- lead_time >  1.05
# |   |   |   |   |   |   |   |   |--- stays_in_weekend_nights <= -0.45
# |   |   |   |   |   |   |   |   |   |--- class: 8.0
# |   |   |   |   |   |   |   |   |--- stays_in_weekend_nights >  -0.45
# |   |   |   |   |   |   |   |   |   |--- class: 7.0
# |   |   |   |--- direct_channel >  0.96
# |   |   |   |   |--- arrival_date_week_number <= -1.06
# |   |   |   |   |   |--- children <= 1.01
# |   |   |   |   |   |   |--- lead_time <= -0.54
# |   |   |   |   |   |   |   |--- adults <= 1.31
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= -1.20
# |   |   |   |   |   |   |   |   |   |--- adults <= -0.68
# |   |   |   |   |   |   |   |   |   |   |--- previous_bookings_not_canceled <= 2.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- previous_bookings_not_canceled >  2.16
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |   |   |--- adults >  -0.68
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  -1.20
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= -0.72
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  -0.72
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |--- adults >  1.31
# |   |   |   |   |   |   |   |   |--- stay_length <= -0.76
# |   |   |   |   |   |   |   |   |   |--- class: 8.0
# |   |   |   |   |   |   |   |   |--- stay_length >  -0.76
# |   |   |   |   |   |   |   |   |   |--- stays_in_weekend_nights <= 0.57
# |   |   |   |   |   |   |   |   |   |   |--- total_of_special_requests <= -0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- total_of_special_requests >  -0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- stays_in_weekend_nights >  0.57
# |   |   |   |   |   |   |   |   |   |   |--- class: 6.0
# |   |   |   |   |   |   |--- lead_time >  -0.54
# |   |   |   |   |   |   |   |--- groups_segment <= 1.37
# |   |   |   |   |   |   |   |   |--- adults <= 1.31
# |   |   |   |   |   |   |   |   |   |--- stays_in_weekend_nights <= 0.57
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= 0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- stays_in_weekend_nights >  0.57
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- adults >  1.31
# |   |   |   |   |   |   |   |   |   |--- is_international <= 0.53
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- is_international >  0.53
# |   |   |   |   |   |   |   |   |   |   |--- class: 6.0
# |   |   |   |   |   |   |   |--- groups_segment >  1.37
# |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |--- children >  1.01
# |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.10
# |   |   |   |   |   |   |   |--- stay_length <= 0.03
# |   |   |   |   |   |   |   |   |--- stays_in_week_nights <= -0.52
# |   |   |   |   |   |   |   |   |   |--- adults <= -1.67
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- adults >  -1.67
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= -1.42
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  -1.42
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- stays_in_week_nights >  -0.52
# |   |   |   |   |   |   |   |   |   |--- required_car_parking_spaces <= 1.33
# |   |   |   |   |   |   |   |   |   |   |--- adults <= 1.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- adults >  1.31
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 11.0
# |   |   |   |   |   |   |   |   |   |--- required_car_parking_spaces >  1.33
# |   |   |   |   |   |   |   |   |   |   |--- class: 8.0
# |   |   |   |   |   |   |   |--- stay_length >  0.03
# |   |   |   |   |   |   |   |   |--- total_of_special_requests <= -0.27
# |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights <= 0.54
# |   |   |   |   |   |   |   |   |   |   |--- adults <= -1.67
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |   |--- adults >  -1.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights >  0.54
# |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |--- total_of_special_requests >  -0.27
# |   |   |   |   |   |   |   |   |   |--- children <= 3.55
# |   |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- children >  3.55
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.86
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 7.0
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.86
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 6.0
# |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.10
# |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.56
# |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.56
# |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |--- arrival_date_week_number >  -1.06
# |   |   |   |   |   |--- arrival_date_month <= 1.27
# |   |   |   |   |   |   |--- lead_time <= 1.02
# |   |   |   |   |   |   |   |--- children <= 1.01
# |   |   |   |   |   |   |   |   |--- lead_time <= -0.28
# |   |   |   |   |   |   |   |   |   |--- adults <= 1.31
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= 0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 24
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |--- adults >  1.31
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- lead_time >  -0.28
# |   |   |   |   |   |   |   |   |   |--- adults <= 1.31
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= -0.91
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  -0.91
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 22
# |   |   |   |   |   |   |   |   |   |--- adults >  1.31
# |   |   |   |   |   |   |   |   |   |   |--- holiday <= 2.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- holiday >  2.28
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 7.0
# |   |   |   |   |   |   |   |--- children >  1.01
# |   |   |   |   |   |   |   |   |--- children <= 3.55
# |   |   |   |   |   |   |   |   |   |--- adults <= 1.31
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- adults >  1.31
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- children >  3.55
# |   |   |   |   |   |   |   |   |   |--- adults <= -0.68
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |   |   |--- adults >  -0.68
# |   |   |   |   |   |   |   |   |   |   |--- stay_length <= 0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- stay_length >  0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |--- lead_time >  1.02
# |   |   |   |   |   |   |   |--- children <= 1.01
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= -0.11
# |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= -0.26
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= -1.41
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  -1.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  -0.26
# |   |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights <= -0.52
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 6.0
# |   |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights >  -0.52
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  -0.11
# |   |   |   |   |   |   |   |   |   |--- adults <= 1.31
# |   |   |   |   |   |   |   |   |   |   |--- required_car_parking_spaces <= 1.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- required_car_parking_spaces >  1.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- adults >  1.31
# |   |   |   |   |   |   |   |   |   |   |--- stays_in_weekend_nights <= -0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 6.0
# |   |   |   |   |   |   |   |   |   |   |--- stays_in_weekend_nights >  -0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- children >  1.01
# |   |   |   |   |   |   |   |   |--- stays_in_weekend_nights <= 0.57
# |   |   |   |   |   |   |   |   |   |--- children <= 6.09
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- children >  6.09
# |   |   |   |   |   |   |   |   |   |   |--- class: 10.0
# |   |   |   |   |   |   |   |   |--- stays_in_weekend_nights >  0.57
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= -1.18
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= 1.12
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 6.0
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  1.12
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 7.0
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  -1.18
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= 1.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  1.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- arrival_date_month >  1.27
# |   |   |   |   |   |   |--- arrival_date_week_number <= 1.84
# |   |   |   |   |   |   |   |--- adults <= 1.31
# |   |   |   |   |   |   |   |   |--- is_international <= 0.53
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= -0.61
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= -1.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  -1.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  -0.61
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- is_international >  0.53
# |   |   |   |   |   |   |   |   |   |--- is_repeated_guest <= 2.43
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- is_repeated_guest >  2.43
# |   |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights <= -1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 6.0
# |   |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights >  -1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- adults >  1.31
# |   |   |   |   |   |   |   |   |--- booking_changes <= 0.30
# |   |   |   |   |   |   |   |   |   |--- total_of_special_requests <= 2.13
# |   |   |   |   |   |   |   |   |   |   |--- holiday <= 2.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- holiday >  2.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- total_of_special_requests >  2.13
# |   |   |   |   |   |   |   |   |   |   |--- class: 8.0
# |   |   |   |   |   |   |   |   |--- booking_changes >  0.30
# |   |   |   |   |   |   |   |   |   |--- stay_length <= -0.56
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |   |--- stay_length >  -0.56
# |   |   |   |   |   |   |   |   |   |   |--- class: 8.0
# |   |   |   |   |   |   |--- arrival_date_week_number >  1.84
# |   |   |   |   |   |   |   |--- lead_time <= -0.26
# |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.16
# |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.16
# |   |   |   |   |   |   |   |   |   |--- children <= 3.55
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.56
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.56
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- children >  3.55
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.88
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 7.0
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- lead_time >  -0.26
# |   |   |   |   |   |   |   |   |--- children <= 1.01
# |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights <= 0.54
# |   |   |   |   |   |   |   |   |   |   |--- stay_length <= -0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- stay_length >  -0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights >  0.54
# |   |   |   |   |   |   |   |   |   |   |--- total_of_special_requests <= 0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- total_of_special_requests >  0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- children >  1.01
# |   |   |   |   |   |   |   |   |   |--- lead_time <= 0.46
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.33
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- lead_time >  0.46
# |   |   |   |   |   |   |   |   |   |   |--- class: 6.0
# |   |   |--- lead_time >  2.29
# |   |   |   |--- adults <= -0.68
# |   |   |   |   |--- stay_length <= 0.03
# |   |   |   |   |   |--- stay_length <= -0.76
# |   |   |   |   |   |   |--- lead_time <= 2.88
# |   |   |   |   |   |   |   |--- is_international <= 0.53
# |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |--- is_international >  0.53
# |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |--- lead_time >  2.88
# |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |--- stay_length >  -0.76
# |   |   |   |   |   |   |--- booking_changes <= 0.30
# |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 0.82
# |   |   |   |   |   |   |   |   |--- lead_time <= 2.56
# |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |--- lead_time >  2.56
# |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  0.82
# |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |--- booking_changes >  0.30
# |   |   |   |   |   |   |   |--- is_international <= 0.53
# |   |   |   |   |   |   |   |   |--- lead_time <= 3.69
# |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |--- lead_time >  3.69
# |   |   |   |   |   |   |   |   |   |--- lead_time <= 3.90
# |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |--- lead_time >  3.90
# |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |--- is_international >  0.53
# |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 0.13
# |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  0.13
# |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |--- stay_length >  0.03
# |   |   |   |   |   |--- stays_in_week_nights <= 0.54
# |   |   |   |   |   |   |--- direct_channel <= 0.96
# |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |--- direct_channel >  0.96
# |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |--- stays_in_week_nights >  0.54
# |   |   |   |   |   |   |--- offline_ta_to_segment <= 0.70
# |   |   |   |   |   |   |   |--- class: 8.0
# |   |   |   |   |   |   |--- offline_ta_to_segment >  0.70
# |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 0.36
# |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  0.36
# |   |   |   |   |   |   |   |   |--- stay_length <= 0.43
# |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |--- stay_length >  0.43
# |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |--- adults >  -0.68
# |   |   |   |   |--- arrival_date_week_number <= -0.48
# |   |   |   |   |   |--- lead_time <= 3.16
# |   |   |   |   |   |   |--- groups_segment <= 1.37
# |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= -0.95
# |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  -0.95
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= -0.55
# |   |   |   |   |   |   |   |   |   |--- adults <= 1.31
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= -0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  -0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- adults >  1.31
# |   |   |   |   |   |   |   |   |   |   |--- children <= 1.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |   |   |   |--- children >  1.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 9.0
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  -0.55
# |   |   |   |   |   |   |   |   |   |--- lead_time <= 2.43
# |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |--- lead_time >  2.43
# |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |--- groups_segment >  1.37
# |   |   |   |   |   |   |   |--- booking_changes <= 0.30
# |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |--- booking_changes >  0.30
# |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |--- lead_time >  3.16
# |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |--- arrival_date_week_number >  -0.48
# |   |   |   |   |   |--- stay_length <= 0.43
# |   |   |   |   |   |   |--- arrival_date_week_number <= 0.65
# |   |   |   |   |   |   |   |--- stay_length <= -0.76
# |   |   |   |   |   |   |   |   |--- lead_time <= 2.91
# |   |   |   |   |   |   |   |   |   |--- booking_changes <= 0.30
# |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |--- booking_changes >  0.30
# |   |   |   |   |   |   |   |   |   |   |--- booking_changes <= 2.41
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |   |   |   |--- booking_changes >  2.41
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 8.0
# |   |   |   |   |   |   |   |   |--- lead_time >  2.91
# |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |--- stay_length >  -0.76
# |   |   |   |   |   |   |   |   |--- direct_channel <= 0.96
# |   |   |   |   |   |   |   |   |   |--- adults <= 1.31
# |   |   |   |   |   |   |   |   |   |   |--- stay_length <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- stay_length >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- adults >  1.31
# |   |   |   |   |   |   |   |   |   |   |--- class: 7.0
# |   |   |   |   |   |   |   |   |--- direct_channel >  0.96
# ...
# |   |   |   |   |   |   |   |   |   |   |--- stay_length >  -0.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.83
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= -1.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  -1.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  0.30
# |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.86
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 0.42
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  0.42
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.86
# |   |   |   |   |   |   |   |   |   |   |--- with_company <= 1.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- with_company >  1.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- adults >  1.31
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= 1.45
# |   |   |   |   |   |   |   |   |   |--- stay_length <= -0.76
# |   |   |   |   |   |   |   |   |   |   |--- class: 6.0
# |   |   |   |   |   |   |   |   |   |--- stay_length >  -0.76
# |   |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights <= 0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights >  0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  1.45
# |   |   |   |   |   |   |   |   |   |--- direct_channel <= 0.96
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= 1.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  1.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- direct_channel >  0.96
# |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |--- children >  3.55
# |   |   |   |   |   |   |   |--- arrival_date_month <= 1.27
# |   |   |   |   |   |   |   |   |--- required_car_parking_spaces <= 1.33
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 0.82
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= -0.89
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  -0.89
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  0.82
# |   |   |   |   |   |   |   |   |   |   |--- stay_length <= 0.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- stay_length >  0.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- required_car_parking_spaces >  1.33
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= -0.32
# |   |   |   |   |   |   |   |   |   |   |--- is_transient_party <= 0.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- is_transient_party >  0.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  -0.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 6.0
# |   |   |   |   |   |   |   |--- arrival_date_month >  1.27
# |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.39
# |   |   |   |   |   |   |   |   |   |--- with_company <= 1.67
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |--- with_company >  1.67
# |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.39
# |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.86
# |   |   |   |   |   |   |   |   |   |   |--- required_car_parking_spaces <= 1.33
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |   |   |   |--- required_car_parking_spaces >  1.33
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 6.0
# |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.86
# |   |   |   |   |   |   |   |   |   |   |--- class: 7.0
# |   |   |   |   |--- offline_ta_to_segment >  0.70
# |   |   |   |   |   |--- lead_time <= -0.28
# |   |   |   |   |   |   |--- stays_in_weekend_nights <= 0.57
# |   |   |   |   |   |   |   |--- holiday <= 2.28
# |   |   |   |   |   |   |   |   |--- stay_length <= -0.76
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.44
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= 1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.44
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- stay_length >  -0.76
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= -0.61
# |   |   |   |   |   |   |   |   |   |   |--- weekend_current_stay <= -0.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- weekend_current_stay >  -0.13
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  -0.61
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= -0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  -0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |--- holiday >  2.28
# |   |   |   |   |   |   |   |   |--- stays_in_weekend_nights <= -0.45
# |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.72
# |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.72
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.16
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- stays_in_weekend_nights >  -0.45
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |--- stays_in_weekend_nights >  0.57
# |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.22
# |   |   |   |   |   |   |   |   |--- adults <= 1.31
# |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= 1.34
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  1.34
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- adults >  1.31
# |   |   |   |   |   |   |   |   |   |--- is_transient <= -0.47
# |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |   |   |--- is_transient >  -0.47
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= 1.23
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  1.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.22
# |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 1.67
# |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.30
# |   |   |   |   |   |   |   |   |   |   |--- total_of_special_requests <= -0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |   |--- total_of_special_requests >  -0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.30
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  1.67
# |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.54
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.54
# |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |--- lead_time >  -0.28
# |   |   |   |   |   |   |--- arrival_date_day_of_month <= 0.76
# |   |   |   |   |   |   |   |--- stays_in_weekend_nights <= 0.57
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= 1.41
# |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.09
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.09
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= -0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  -0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  1.41
# |   |   |   |   |   |   |   |   |   |--- booking_changes <= 0.30
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- booking_changes >  0.30
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= 1.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  1.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |--- stays_in_weekend_nights >  0.57
# |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 0.53
# |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights <= 2.64
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month <= 0.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  0.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- stays_in_week_nights >  2.64
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= 1.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  1.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- arrival_date_day_of_month >  0.53
# |   |   |   |   |   |   |   |   |   |--- stay_length <= 0.82
# |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |--- stay_length >  0.82
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= -0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  -0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |--- arrival_date_day_of_month >  0.76
# |   |   |   |   |   |   |   |--- arrival_date_week_number <= 1.84
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number <= 1.26
# |   |   |   |   |   |   |   |   |   |--- lead_time <= 0.31
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= 0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |--- lead_time >  0.31
# |   |   |   |   |   |   |   |   |   |   |--- children <= 1.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- children >  1.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- arrival_date_week_number >  1.26
# |   |   |   |   |   |   |   |   |   |--- lead_time <= 0.16
# |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |--- lead_time >  0.16
# |   |   |   |   |   |   |   |   |   |   |--- lead_time <= 0.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |   |--- lead_time >  0.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |--- arrival_date_week_number >  1.84
# |   |   |   |   |   |   |   |   |--- lead_time <= 0.10
# |   |   |   |   |   |   |   |   |   |--- stay_length <= -0.36
# |   |   |   |   |   |   |   |   |   |   |--- class: 7.0
# |   |   |   |   |   |   |   |   |   |--- stay_length >  -0.36
# |   |   |   |   |   |   |   |   |   |   |--- weekend_current_stay <= -0.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 6.0
# |   |   |   |   |   |   |   |   |   |   |--- weekend_current_stay >  -0.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5.0
# |   |   |   |   |   |   |   |   |--- lead_time >  0.10
# |   |   |   |   |   |   |   |   |   |--- lead_time <= 0.36
# |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# |   |   |   |   |   |   |   |   |   |--- lead_time >  0.36
# |   |   |   |   |   |   |   |   |   |   |--- booking_changes <= 1.71
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4.0
# |   |   |   |   |   |   |   |   |   |   |--- booking_changes >  1.71
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 3.0
# {'PC0': 'corporate_channel', 'PC1': 'is_transient', 'PC2': 'stay_length', 'PC3': 'direct_channel', 'PC4': 'arrival_date_week_number', 'PC5': 'refundable_deposit', 'PC6': 'previous_cancellations', 'PC7': 'offline_ta_to_segment', 'PC8': 'is_resort', 'PC9': 'arrival_date_day_of_month', 'PC10': 'is_group', 'PC11': 'babies', 'PC12': 'is_contract', 'PC13': 'gds_channel', 'PC14': 'aviation_segment', 'PC15': 'children', 'PC16': 'weekend_current_stay', 'PC17': 'gds_channel', 'PC18': 'required_car_parking_spaces', 'PC19': 'holiday', 'PC20': 'babies', 'PC21': 'is_international', 'PC22': 'adults', 'PC23': 'is_repeated_guest', 'PC24': 'is_resort', 'PC25': 'lead_time', 'PC26': 'groups_segment'}

# %% [markdown]
# ### Decision Tree Regression, No PCA

# %%
X_train, y_train, X_test, y_test = make_dataset(df, features, binned=False)
y_hat, rmse = tree_reg(X_train, y_train, X_test, y_test)
plot_y(y_hat, y_test)
plot_err_hist(y_hat, y_test, rmse)
# Out:
# Total Size of data:  72514
# Feature ['lead_time', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'required_car_parking_spaces', 'total_of_special_requests', 'is_resort', 'bought_meal', 'is_international', 'aviation_segment', 'corporate_segment', 'groups_segment', 'offline_ta_to_segment', 'online_ta_segment', 'corporate_channel', 'direct_channel', 'gds_channel', 'ta_to_channel', 'no_deposit', 'refundable_deposit', 'nonrefundable_deposit', 'with_company', 'is_contract', 'is_group', 'is_transient', 'is_transient_party', 'stay_length', 'holiday', 'weekend_current_stay']
# X_train:  (50760, 38)
# y_train:  (50760,)
# X_test:  (21754, 38)
# y_test:  (21754,)
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:24: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   X_test = X[ind]
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:25: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   y_test = y[ind]
# Root Mean Square Error:  30.24082807738604

# %% [markdown]
# ### Decision Tree Regression, With PCA

# %%
X_train, y_train, X_test, y_test = make_dataset(df, features, binned=False)
X_train_pca, X_test_pca, col_dic = make_PCA(X_train, X_test, features, thresh=.95)
y_hat, rmse = tree_reg(X_train_pca, y_train, X_test_pca, y_test)
plot_y(y_hat, y_test)
plot_err_hist(y_hat, y_test, rmse)
# Out:
# Total Size of data:  72514
# Feature ['lead_time', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'required_car_parking_spaces', 'total_of_special_requests', 'is_resort', 'bought_meal', 'is_international', 'aviation_segment', 'corporate_segment', 'groups_segment', 'offline_ta_to_segment', 'online_ta_segment', 'corporate_channel', 'direct_channel', 'gds_channel', 'ta_to_channel', 'no_deposit', 'refundable_deposit', 'nonrefundable_deposit', 'with_company', 'is_contract', 'is_group', 'is_transient', 'is_transient_party', 'stay_length', 'holiday', 'weekend_current_stay']
# X_train:  (50760, 38)
# y_train:  (50760,)
# X_test:  (21754, 38)
# y_test:  (21754,)
# number components:  27
# Explained Variance: 0.9622491847007217
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:24: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   X_test = X[ind]
# C:\Users\KATYLU~2\AppData\Local\Temp/ipykernel_3152/1572250069.py:25: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   y_test = y[ind]
# Root Mean Square Error:  37.11952157627566
